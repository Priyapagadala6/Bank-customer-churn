# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
# Get Dataset File Path
# path = os.path.abspath("")
# Alternatively
path = os.getcwd()
file = path + "\Customer-Churn-Records.csv"
file
# Out:
# 'C:\\Users\\gopi naga priya\\DAP\\Customer-Churn-Records.csv'

# %%
# Load Cars Dataset
df = pd.read_csv(file)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction_Score Card Type  \
# 0           101348.88       1         1                   2   DIAMOND
# 1           112542.58       0         1                   3   DIAMOND
# 2           113931.57       1         1                   3   DIAMOND
# 3            93826.63       0         0                   5      GOLD
# 4            79084.10       0         0                   5      GOLD
# ...               ...     ...       ...                 ...       ...
# 9995         96270.64       0         0                   1   DIAMOND
# 9996        101699.77       0         0                   5  PLATINUM
# 9997         42085.58       1         1                   3    SILVER
# 9998         92888.52       1         1                   2      GOLD
# 9999         38190.78       0         0                   3   DIAMOND
#
#       Point Earned
# 0              464
# 1              456
# 2              377
# 3              350
# 4              425
# ...            ...
# 9995           300
# 9996           771
# 9997           564
# 9998           339
# 9999           911
#
# [10000 rows x 18 columns]

# %% [markdown]
# ## Size of the Data

# %%
# Get Size of Dataset (Rows and Columns)
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# ## Total Columns

# %%
# Get Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
#  15  Satisfaction_Score  10000 non-null  int64
#  16  Card Type           10000 non-null  object
#  17  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 1.4+ MB

# %%
# Print Column Names Only
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction_Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %% [markdown]
# ## Check for Null Values

# %%
# To find the total no.of rows which are missing value in a column
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction_Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# ## Head and Tail

# %%
# Get Top 5 Records
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction_Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %%
# Get Last 5 Records
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction_Score Card Type  \
# 9995         96270.64       0         0                   1   DIAMOND
# 9996        101699.77       0         0                   5  PLATINUM
# 9997         42085.58       1         1                   3    SILVER
# 9998         92888.52       1         1                   2      GOLD
# 9999         38190.78       0         0                   3   DIAMOND
#
#       Point Earned
# 9995           300
# 9996           771
# 9997           564
# 9998           339
# 9999           911

# %% [markdown]
# ## Numerical  columns

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
numerical_columns = data_types[data_types != 'object'].index.tolist()
#categorical_columns = data_types[data_types == 'object'].index.tolist()

print("Numerical columns:", numerical_columns)
#print("\nCategorical columns:", categorical_columns)
# Out:
# Numerical columns: ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain', 'Satisfaction_Score', 'Point Earned']

# %%
# Get information about numerical columns
numerical_info = df.describe()

# Get information about categorical columns
categorical_info = {}
for column in df.select_dtypes(include=['object']):
    categorical_info[column] = df[column].value_counts()

# Print information about numerical columns
print("Numerical column information:")
print(numerical_info)

# Print information about categorical columns
print("\nCategorical column information:")
for column, info in categorical_info.items():
    print(f"\nColumn: {column}")
    print(info)
# Out:
# Numerical column information:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction_Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000
#
# Categorical column information:
#
# Column: Surname
# Surname
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: count, Length: 2932, dtype: int64
#
# Column: Geography
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
#
# Column: Gender
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64
#
# Column: Card Type
# Card Type
# DIAMOND     2507
# GOLD        2502
# SILVER      2496
# PLATINUM    2495
# Name: count, dtype: int64

# %% [markdown]
# ## Plots

# %%
df1 = df[['CreditScore','Balance','NumOfProducts','HasCrCard','IsActiveMember','Complain','Satisfaction_Score','Tenure','Age','EstimatedSalary']]
df1
# Create subplots for the histograms
plt.figure(figsize=(12, 18))
for i, var in enumerate(df1, 1):
 plt.subplot(6, 2, i)
 sns.histplot(df[var], bins=20, kde=True)
 plt.title(f'Histogram of {var}')
 plt.xlabel(var)
 plt.ylabel('Overall')
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Box plot

# %%
df1 = df[['CreditScore','Balance','NumOfProducts','HasCrCard','IsActiveMember','Complain','Satisfaction_Score','Tenure','Age','EstimatedSalary']]
df1
# Create subplots for the histograms
plt.figure(figsize=(8, 18))
for i, var in enumerate(df1, 1):
 plt.subplot(6, 2, i)
 sns.boxplot(y=var, data=df)
 plt.title(f'Box Plot of {var}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical columns

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
#numerical_columns = data_types[data_types != 'object'].index.tolist()
categorical_columns = data_types[data_types == 'object'].index.tolist()

#print("Numerical columns:", numerical_columns)
print("\nCategorical columns:", categorical_columns)
# Out:
# Categorical columns: ['Surname', 'Geography', 'Gender', 'Card Type']

# %% [markdown]
# ## Bar Plot

# %%
#df['Geography'] contains the 'Geography' feature with values 'France', 'Spain', and 'Germany'

# Count the occurrences of each category
geography_counts = df['Geography'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=geography_counts.index, y=geography_counts.values)
plt.title('Distribution of Customers by Geography')
plt.xlabel('Geography')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each category
CardType_counts = df['Card Type'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=CardType_counts.index, y=CardType_counts.values)
plt.title('Distribution of Customers by Card Type')
plt.xlabel('Card Type')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each category
Gender_counts = df['Gender'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=Gender_counts.index, y=Gender_counts.values)
plt.title('Distribution of Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Count the occurrences of each category
geography_counts = df['Geography'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(geography_counts, labels=geography_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Customers by Geography')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Count the occurrences of each category
CardType_counts = df['Card Type'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(CardType_counts, labels=CardType_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Customers by Card Type')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Count the occurrences of each category
Gender_counts = df['Gender'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(Gender_counts, labels=Gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Customers by Gender')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ## Count Plot

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Geography'].value_counts().index
sns.countplot(x=df['Geography'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Geography')
plt.ylabel('Exited')
plt.show()

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Card Type'].value_counts().index
sns.countplot(x=df['Card Type'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Card Type')
plt.ylabel('Exited')
plt.show()

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Gender'].value_counts().index
sns.countplot(x=df['Gender'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Gender')
plt.ylabel('Exited')
plt.show()

# %% [markdown]
# ## Pre Processing

# %% [markdown]
# ### Dealing with Missing Values

# %%
# This will display rows with at least one null value across all columns
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited, Complain, Satisfaction_Score, Card Type, Point Earned]
# Index: []

# %%
# This will display all duplicate rows (excluding the first occurrence)
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited, Complain, Satisfaction_Score, Card Type, Point Earned]
# Index: []

# %%
# Remove Duplicate Rows, ifany
# Keep first row and remove other duplicate rows of that row
df = df.drop_duplicates(keep='first')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction_Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %% [markdown]
# ## Droping unwanted columns

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['RowNumber'],axis=1, inplace=True)
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Complain  Satisfaction_Score Card Type  Point Earned
# 0       1         1                   2   DIAMOND           464
# 1       0         1                   3   DIAMOND           456
# 2       1         1                   3   DIAMOND           377
# 3       0         0                   5      GOLD           350
# 4       0         0                   5      GOLD           425

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['CustomerId'],axis=1, inplace=True)
df.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Complain  Satisfaction_Score Card Type  Point Earned
# 0         1                   2   DIAMOND           464
# 1         1                   3   DIAMOND           456
# 2         1                   3   DIAMOND           377
# 3         0                   5      GOLD           350
# 4         0                   5      GOLD           425

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['Surname'],axis=1, inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Point Earned
# 0                   2   DIAMOND           464
# 1                   3   DIAMOND           456
# 2                   3   DIAMOND           377
# 3                   5      GOLD           350
# 4                   5      GOLD           425

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['Point Earned'],axis=1, inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type
# 0                   2   DIAMOND
# 1                   3   DIAMOND
# 2                   3   DIAMOND
# 3                   5      GOLD
# 4                   5      GOLD

# %% [markdown]
# ## Encoding Techniques

# %% [markdown]
# ## Transforming Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Gender_encoded'] = label_encoder.fit_transform(df['Gender'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Gender' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Gender' column:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Gender_encoded
# 0                   2   DIAMOND               0
# 1                   3   DIAMOND               0
# 2                   3   DIAMOND               0
# 3                   5      GOLD               0
# 4                   5      GOLD               0

# %% [markdown]
# #### After one-hot encoding for the column "Gender" the value for Female,Male respectively is 1 and 0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Geography" column
df['Geography_encoded'] = label_encoder.fit_transform(df['Geography'])

# Display the DataFrame with encoded "Geography"
print("DataFrame with encoded 'Geography' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Geography' column:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Gender_encoded  Geography_encoded
# 0                   2   DIAMOND               0                  0
# 1                   3   DIAMOND               0                  2
# 2                   3   DIAMOND               0                  0
# 3                   5      GOLD               0                  0
# 4                   5      GOLD               0                  2

# %% [markdown]
# #### After one-hot encoding for the column "Geography" the value for France,Germany,Spain respectively is 0,1,2

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Card type" column
df['Card type_encoded'] = label_encoder.fit_transform(df['Card Type'])

# Display the DataFrame with encoded "Card type"
print("DataFrame with encoded 'Card Type' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Card Type' column:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Gender_encoded  Geography_encoded  \
# 0                   2   DIAMOND               0                  0
# 1                   3   DIAMOND               0                  2
# 2                   3   DIAMOND               0                  0
# 3                   5      GOLD               0                  0
# 4                   5      GOLD               0                  2
#
#    Card type_encoded
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  1

# %% [markdown]
# #### After label encoding for the column "Card Type" the value for Diamond,Gold,Platinum and Silver respectively is 0,1,2,3

# %% [markdown]
# ### Scaling the numerical columns

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the column to be scaled
column_to_scale = df['Tenure']

# Reshape the column into a 2D array
reshaped_column = column_to_scale.values.reshape(-1, 1)

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max scaling to the column
scaled_column = scaler.fit_transform(reshaped_column)

# Replace the original column with the scaled values
df['Tenure'] = scaled_column

# Display the DataFrame after scaling
print("DataFrame after scaling 'Tenure' with MinMaxScaler:")
print(df.head())
# Out:
# DataFrame after scaling 'Tenure' with MinMaxScaler:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42     0.2       0.00              1
# 1          608     Spain  Female   41     0.1   83807.86              1
# 2          502    France  Female   42     0.8  159660.80              3
# 3          699    France  Female   39     0.1       0.00              2
# 4          850     Spain  Female   43     0.2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Gender_encoded  Geography_encoded  \
# 0                   2   DIAMOND               0                  0
# 1                   3   DIAMOND               0                  2
# 2                   3   DIAMOND               0                  0
# 3                   5      GOLD               0                  0
# 4                   5      GOLD               0                  2
#
#    Card type_encoded
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  1

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the column to be scaled
column_to_scale = df['CreditScore']

# Reshape the column into a 2D array
reshaped_column = column_to_scale.values.reshape(-1, 1)

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max scaling to the column
scaled_column = scaler.fit_transform(reshaped_column)

# Replace the original column with the scaled values
df['CreditScore'] = scaled_column

# Display the DataFrame after scaling
print("DataFrame after scaling 'CreditScore' with MinMaxScaler:")
print(df.head())
# Out:
# DataFrame after scaling 'CreditScore' with MinMaxScaler:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0        0.538    France  Female   42     0.2       0.00              1
# 1        0.516     Spain  Female   41     0.1   83807.86              1
# 2        0.304    France  Female   42     0.8  159660.80              3
# 3        0.698    France  Female   39     0.1       0.00              2
# 4        1.000     Spain  Female   43     0.2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction_Score Card Type  Gender_encoded  Geography_encoded  \
# 0                   2   DIAMOND               0                  0
# 1                   3   DIAMOND               0                  2
# 2                   3   DIAMOND               0                  0
# 3                   5      GOLD               0                  0
# 4                   5      GOLD               0                  2
#
#    Card type_encoded
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  1

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
numerical_columns = data_types[data_types != 'object'].index.tolist()
categorical_columns = data_types[data_types == 'object'].index.tolist()

print("Numerical columns:", numerical_columns)
print("\nCategorical columns:", categorical_columns)
# Out:
# Numerical columns: ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain', 'Satisfaction_Score', 'Gender_encoded', 'Geography_encoded', 'Card type_encoded']
#
# Categorical columns: ['Geography', 'Gender', 'Card Type']

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Complain', 'Satisfaction_Score', 'Card Type',
#        'Gender_encoded', 'Geography_encoded', 'Card type_encoded'],
#       dtype='object')

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['Gender', 'Geography','Card Type'],axis=1, inplace=True)
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0        0.538   42     0.2       0.00              1          1
# 1        0.516   41     0.1   83807.86              1          0
# 2        0.304   42     0.8  159660.80              3          1
# 3        0.698   39     0.1       0.00              2          0
# 4        1.000   43     0.2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction_Score  \
# 0               1        101348.88       1         1                   2
# 1               1        112542.58       0         1                   3
# 2               0        113931.57       1         1                   3
# 3               0         93826.63       0         0                   5
# 4               1         79084.10       0         0                   5
#
#    Gender_encoded  Geography_encoded  Card type_encoded
# 0               0                  0                  0
# 1               0                  2                  0
# 2               0                  0                  0
# 3               0                  0                  1
# 4               0                  2                  1

# %%
df.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction_Score', 'Gender_encoded', 'Geography_encoded',
#        'Card type_encoded'],
#       dtype='object')

# %% [markdown]
# ## Visualisation

# %%
#Scatterplot using matplot library
plt.scatter(df['Age'],df['CreditScore'])
plt.colorbar(label='Exited')
plt.title('Scatter plot of age vs creditscore')
plt.xlabel('Age')
plt.ylabel('CreditScore')
plt.show()

# %%
#Lineplot using matplot library
plt.plot(df['Age'])
plt.plot(df['Balance'])
plt.title('Lineplot')
plt.xlabel('Age')
plt.ylabel('Balance')
plt.show()

# %%
#Scatterplot using seaborn library
sns.scatterplot(x='Age',y='CreditScore',data=df,hue='Exited')
plt.title('Scatter plot of age vs creditscore')
plt.xlabel('Age')
plt.ylabel('CreditScore')
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()
# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Sort correlations for 'Exited' column in descending order
sorted_corr_Exited = correlation_matrix['Exited'].sort_values(ascending=False)
sorted_corr_Exited

# %% [markdown]
# ### <span style='color:blue'>Apply Machine Learning Algorithm</span>

# %% [markdown]
# ### Selecting X and Y variables

# %%
#Features selected for prediction
x = df[['Complain','Age','Balance','EstimatedSalary','HasCrCard','Tenure','NumOfProducts','IsActiveMember','CreditScore','Satisfaction_Score']]
x
# Out:
#       Complain  Age    Balance  EstimatedSalary  HasCrCard  Tenure  \
# 0            1   42       0.00        101348.88          1     0.2
# 1            1   41   83807.86        112542.58          0     0.1
# 2            1   42  159660.80        113931.57          1     0.8
# 3            0   39       0.00         93826.63          0     0.1
# 4            0   43  125510.82         79084.10          1     0.2
# ...        ...  ...        ...              ...        ...     ...
# 9995         0   39       0.00         96270.64          1     0.5
# 9996         0   35   57369.61        101699.77          1     1.0
# 9997         1   36       0.00         42085.58          0     0.7
# 9998         1   42   75075.31         92888.52          1     0.3
# 9999         0   28  130142.79         38190.78          1     0.4
#
#       NumOfProducts  IsActiveMember  CreditScore  Satisfaction_Score
# 0                 1               1        0.538                   2
# 1                 1               1        0.516                   3
# 2                 3               0        0.304                   3
# 3                 2               0        0.698                   5
# 4                 1               1        1.000                   5
# ...             ...             ...          ...                 ...
# 9995              2               0        0.842                   1
# 9996              1               1        0.332                   5
# 9997              1               1        0.718                   3
# 9998              2               0        0.844                   2
# 9999              1               0        0.884                   3
#
# [10000 rows x 10 columns]

# %%
# Select only numeric type of columns by their names as:
y = df[['Exited']]
y
# Out:
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# X_train: (8000, 10)
# X_test: (2000, 10)

# %% [markdown]
# ### Create and Fit Model

# %% [markdown]
# ### Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42)
# Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=42)

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# %% [markdown]
# ## <span style='color:blue'>Evaluate Model</span>

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
# Display the results
print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.80
# Confusion Matrix:
# [[1607    0]
#  [ 393    0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1607
#            1       0.00      0.00      0.00       393
#
#     accuracy                           0.80      2000
#    macro avg       0.40      0.50      0.45      2000
# weighted avg       0.65      0.80      0.72      2000
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# X contains the features excluding the target variable (e.g., Geography, Age, Balance, etc.)
# y contains the target variable (e.g., whether the customer churned or not)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Print confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# C:\Users\gopi naga priya\AppData\Local\Temp\ipykernel_30332\2720076327.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_classifier.fit(X_train, y_train)
# Accuracy: 0.999
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1607
#            1       1.00      1.00      1.00       393
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
#
#
# Confusion Matrix:
# [[1606    1]
#  [   1  392]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# X contains the features (independent variables) and y contains the target variable (dependent variable)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize the Linear Regression model
linear_reg = LinearRegression()

# Train the model on the training data
linear_reg.fit(X_train, y_train)

# Predict the target variable for test data
y_pred = linear_reg.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 0.0009992181694609646
# R-squared: 0.9936713382167967

# %%
x.tail()
# Out:
#       Complain  Age    Balance  EstimatedSalary  HasCrCard  Tenure  \
# 9995         0   39       0.00         96270.64          1     0.5
# 9996         0   35   57369.61        101699.77          1     1.0
# 9997         1   36       0.00         42085.58          0     0.7
# 9998         1   42   75075.31         92888.52          1     0.3
# 9999         0   28  130142.79         38190.78          1     0.4
#
#       NumOfProducts  IsActiveMember  CreditScore  Satisfaction_Score
# 9995              2               0        0.842                   1
# 9996              1               1        0.332                   5
# 9997              1               1        0.718                   3
# 9998              2               0        0.844                   2
# 9999              1               0        0.884                   3

# %%
y.tail()
# Out:
#       Exited
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0

# %%
Complain=1
Age =41
Balance = 83807.86            
EstimatedSalary= 112542.58              
HasCrCard = 0        
Tenure= 1
NumOfProducts =1
IsActiveMember=1 
CreditScore =608
Satisfaction_Score=3
y_pred = rf_classifier.predict([[Complain,Age,Balance,EstimatedSalary,HasCrCard,Tenure,NumOfProducts,IsActiveMember,CreditScore,Satisfaction_Score]])
print(f"Predicted Value: {round(y_pred[0])}")
# Out:
# Predicted Value: 1
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
